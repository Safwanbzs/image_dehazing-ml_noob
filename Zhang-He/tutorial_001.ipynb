# %% [markdown]
# <a href="https://colab.research.google.com/github/Safwanbzs/image_dehazing-ml_noob/blob/main/Zhang-He/tutorial_001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/Safwanbzs/image_dehazing-ml_noob/
# Out:
# Cloning into 'image_dehazing-ml_noob'...
# remote: Enumerating objects: 42, done.
# remote: Counting objects: 100% (42/42), done.
# remote: Compressing objects: 100% (38/38), done.
# remote: Total 42 (delta 13), reused 0 (delta 0), pack-reused 0 (from 0)
# Receiving objects: 100% (42/42), 1.08 MiB | 24.60 MiB/s, done.
# Resolving deltas: 100% (13/13), done.

# %%
cd image_dehazing-ml_noob/Zhang-He
# Out:
# /content/image_dehazing-ml_noob/Zhang-He

# %%
# !pip install opencv-python

# %%
import PIL.Image

# %%
# !python dehazer_v2.py image/16.png
# Out:
# <IPython.core.display.Image object>
# <IPython.core.display.Image object>
# <IPython.core.display.Image object>
# <IPython.core.display.Image object>
# [ WARN:0@0.782] global loadsave.cpp:1089 imwrite_ Unsupported depth image for selected encoder is fallbacked to CV_8U.

# %%
from google.colab import drive
drive.mount('/content/drive')
