# %% [markdown]
# <a href="https://colab.research.google.com/github/Safwanbzs/image_dehazing-ml_noob/blob/main/Boyiliee/learningcnn.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/MayankSingal/PyTorch-Image-Dehazing
# Out:
# Cloning into 'PyTorch-Image-Dehazing'...
# remote: Enumerating objects: 90, done.
# remote: Total 90 (delta 0), reused 0 (delta 0), pack-reused 90 (from 1)
# Receiving objects: 100% (90/90), 11.78 MiB | 30.14 MiB/s, done.
# Resolving deltas: 100% (19/19), done.

# %%
# !pip install gdown

# %%
# !gdown "https://drive.google.com/uc?id=17ZWJOpH1AsYQhoqpWR6PK61HrUhArdAK" -O PyTorch-Image-Dehazing/data.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=17ZWJOpH1AsYQhoqpWR6PK61HrUhArdAK
# From (redirected): https://drive.google.com/uc?id=17ZWJOpH1AsYQhoqpWR6PK61HrUhArdAK&confirm=t&uuid=8fff1072-9523-42a5-b083-fa9e6c68728d
# To: /content/PyTorch-Image-Dehazing/data.zip
# 100% 898M/898M [00:15<00:00, 57.7MB/s]

# %%
cd PyTorch-Image-Dehazing/
mkdir data
ls
# Out:
# /content/PyTorch-Image-Dehazing

# %%
# !unzip data.zip -d data
# Out:
# Streaming output truncated to the last 5000 lines.
#   inflating: data/data/NYU2_76_7_3.jpg
#   inflating: data/data/NYU2_770_1_1.jpg
#   inflating: data/data/NYU2_770_1_2.jpg
#   inflating: data/data/NYU2_770_1_3.jpg
#   inflating: data/data/NYU2_770_2_1.jpg
#   inflating: data/data/NYU2_770_2_2.jpg
#   inflating: data/data/NYU2_770_3_1.jpg
#   inflating: data/data/NYU2_770_3_2.jpg
#   inflating: data/data/NYU2_770_3_3.jpg
#   inflating: data/data/NYU2_770_4_1.jpg
#   inflating: data/data/NYU2_770_4_2.jpg
#   inflating: data/data/NYU2_770_4_3.jpg
#   inflating: data/data/NYU2_770_5_1.jpg
#   inflating: data/data/NYU2_770_5_2.jpg
#   inflating: data/data/NYU2_770_5_3.jpg
#   inflating: data/data/NYU2_770_6_1.jpg
#   inflating: data/data/NYU2_770_6_2.jpg
#   inflating: data/data/NYU2_770_6_3.jpg
#   inflating: data/data/NYU2_770_7_1.jpg
#   inflating: data/data/NYU2_770_7_2.jpg
#   inflating: data/data/NYU2_771_1_1.jpg
#   inflating: data/data/NYU2_771_1_2.jpg
# ...

# %%
# !gdown "https://drive.google.com/uc?id=1Sz5ZFFZXo3sY85R3v7yJa6W6riDGur46" -O testornot.zip
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1Sz5ZFFZXo3sY85R3v7yJa6W6riDGur46
# From (redirected): https://drive.google.com/uc?id=1Sz5ZFFZXo3sY85R3v7yJa6W6riDGur46&confirm=t&uuid=92167f73-ca6c-459a-b45d-bc7b5c9e4a1d
# To: /content/PyTorch-Image-Dehazing/testornot.zip
# 100% 56.7M/56.7M [00:01<00:00, 44.8MB/s]

# %%
# !unzip testornot.zip -d data
# Out:
# Archive:  testornot.zip
#    creating: data/image/
#   inflating: data/image/NYU2_1.jpg
#   inflating: data/image/NYU2_10.jpg
#   inflating: data/image/NYU2_100.jpg
#   inflating: data/image/NYU2_1000.jpg
#   inflating: data/image/NYU2_1001.jpg
#   inflating: data/image/NYU2_1002.jpg
#   inflating: data/image/NYU2_1003.jpg
#   inflating: data/image/NYU2_1004.jpg
#   inflating: data/image/NYU2_1005.jpg
#   inflating: data/image/NYU2_1006.jpg
#   inflating: data/image/NYU2_1007.jpg
#   inflating: data/image/NYU2_1008.jpg
#   inflating: data/image/NYU2_1009.jpg
#   inflating: data/image/NYU2_101.jpg
#   inflating: data/image/NYU2_1010.jpg
#   inflating: data/image/NYU2_1011.jpg
#   inflating: data/image/NYU2_1012.jpg
#   inflating: data/image/NYU2_1013.jpg
#   inflating: data/image/NYU2_1014.jpg
#   inflating: data/image/NYU2_1015.jpg
#   inflating: data/image/NYU2_1016.jpg
#   inflating: data/image/NYU2_1017.jpg
#   inflating: data/image/NYU2_1018.jpg
# ...

# %%
# !mv data/image data/images
# !ls data
# Out:
# data  images

# %%
import PIL.Image
import PIL.ImageFile

# Fix for OSError: image file is truncated (Rethink for general cases)
PIL.ImageFile.LOAD_TRUNCATED_IMAGES = True

# Apply the fix directly to the dataloader.py file
with open('dataloader.py', 'r') as f:
    content = f.read()
# Replace 'PIL.Image.LANCZOS' with 'Image.LANCZOS' as 'Image' is already imported from PIL
content = content.replace('PIL.Image.LANCZOS', 'Image.LANCZOS')
with open('dataloader.py', 'w') as f:
    f.write(content)

# !python train.py
# Out:
# Traceback (most recent call last):
#   File "/content/PyTorch-Image-Dehazing/train.py", line 110, in <module>
#     train(config)
#   File "/content/PyTorch-Image-Dehazing/train.py", line 27, in train
#     dehaze_net = net.dehaze_net().cuda()
#                  ^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1093, in cuda
#     return self._apply(lambda t: t.cuda(device))
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 933, in _apply
#     module._apply(fn)
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 964, in _apply
#     param_applied = fn(param)
#                     ^^^^^^^^^
#   File "/usr/local/lib/python3.12/dist-packages/torch/nn/modules/module.py", line 1093, in <lambda>
#     return self._apply(lambda t: t.cuda(device))
#                                  ^^^^^^^^^^^^^^
# ...
