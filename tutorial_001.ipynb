# %% [markdown]
# <a href="https://colab.research.google.com/github/Safwanbzs/image_dehazing-ml_noob/blob/main/tutorial_001.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !git clone https://github.com/He-Zhang/image_dehaze
# Out:
# Cloning into 'image_dehaze'...
# remote: Enumerating objects: 33, done.
# remote: Counting objects: 100% (6/6), done.
# remote: Compressing objects: 100% (2/2), done.
# remote: Total 33 (delta 4), reused 4 (delta 4), pack-reused 27 (from 1)
# Receiving objects: 100% (33/33), 773.48 KiB | 11.54 MiB/s, done.
# Resolving deltas: 100% (8/8), done.

# %%
cd image_dehaze
# Out:
# /content/image_dehaze

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in /usr/local/lib/python3.12/dist-packages (4.13.0.92)
# Requirement already satisfied: numpy>=2 in /usr/local/lib/python3.12/dist-packages (from opencv-python) (2.0.2)

# %%
import PIL.Image

# %%
# !python dehazer_v2.py image/16.png
# Out:
# <IPython.core.display.Image object>
# <IPython.core.display.Image object>
# <IPython.core.display.Image object>
# <IPython.core.display.Image object>
# [ WARN:0@0.680] global loadsave.cpp:1089 imwrite_ Unsupported depth image for selected encoder is fallbacked to CV_8U.
